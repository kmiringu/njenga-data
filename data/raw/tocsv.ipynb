# %%
import pandas as pd

df1 = pd.read_excel("Construction_cost_index.xlsx")
df2 = pd.read_excel("consumer_index.xlsx")

df11 = df1.to_csv("Construction_cost_index.csv", index= False)
df22 = df2.to_csv("consumer_index.csv", index= False)
